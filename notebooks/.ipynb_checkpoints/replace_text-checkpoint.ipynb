# %% [markdown]
# # Import Packages/Modules
# -----

# %%
import re
import os
import sys
# import shutil

# %%
import argparse

# %%
parser = argparse.ArgumentParser(description="Test args parser")

# %% [markdown]
# ### Define test input/output variables

# %%
fsf_file = "grp.bart.drugs_in_urine.fsf"
# info_file = "files.auxillary/out_1.txt"
fsf_out_file = "out_grp.bart.drugs_in_urine.fsf"

# %% [markdown]
# # Define Functions
# ------

# %%
def read_file(file):
    '''
    Opens the (text) file, reads its contents, and stores those contents in a list of strings. Should the input
    file not exist, then the text is assumed to be a string and is returned instead.

    Arguments:
        file (str, file): Input file or string
    Returns:
        lines (list): List of strings of the file contents
    '''

    if os.path.exists(file) and os.path.isfile(file):
        with open(file, "r") as file:
            lines = file.readlines()
            file.close()
    elif os.path.exists(file) and os.path.isdir(file):
        lines = file
    else:
        lines = file
    return lines

# %%
def regex_replace(pattern,file,repl_list):
    '''
    Uses input pattern for a regEx search. If the pattern is matched in the
    input file, the pattern is replaced with the contents in the 'replace list'
    (repl_list) argument.
    
    Arguments:
        pattern (str): Pattern to be searched and matched
        file (file): Input file that is read and searched
        repl_list (list): List of contents that replaces matched pattern
    Returns:
        new_lines (list): New list of file contents that has replaced the regEx matched pattern
    '''
    
    regexp = re.compile(f"{pattern}")
    new_lines = list()
    with open(file,"r") as f:
        for line in f:
            match = regexp.match(line)
            if match:
                new_lines.extend(repl_list)
            else:
                new_lines.append(line)
        f.close()
    return new_lines

# %%
def write_file(out_file,text_list):
    '''
    Writes output file provided the file contents as a list, and some output file.
    
    N.B.: Output file is overwritten should it already exist.
    
    Arguments:
        out_file (file): Output file name and path.
        text_list (list): File contents stored as a list.
    Returns:
        out_file (file): Written output file.
    '''
    
    with open(out_file,"w") as file:
        file.writelines(text_list)
        file.close()
    return out_file

# %%
# info = read_file(info_file)
# info

# %%
# line_sub = regex_replace("{sub_data}",fsf_file,info)
# type(line_sub)

# %%
# write_file("test.fsf",line_sub)

# %%
def reg_ex_sub(in_file,info_file,pattern,out_file):
    '''
    REgular EXpression SUBstitution is performed via a regEx search, match, and substituion of text from some other
    file.
    
    Arguments:
        in_file (file): Input file to be searched
        info_file (file): File that contains text to replace pattern matched regEx
        pattern (str): Pattern to be searched and matched
        out_file (file): Output file to be written to
    Returns:
        out_file (file): Output file with text from info_file replacing the matched pattern in in_file
    '''
    
    info = read_file(file=info_file)
    line_sub = regex_replace(pattern=pattern,file=in_file,repl_list=info)
    out_file = write_file(out_file=out_file,text_list=line_sub)
    return out_file

# %%
# reg_ex_sub(fsf_file,info_file,"{sub_data}",'test.2.fsf')

# %%
# list_1 = ['test1','test2']
# list_2 = ['file_1','file_2']

# %%
# if len(list_1) == len(list_2) and len(list_1) > 1:
#     print("True")

# %%
# for i,idx in enumerate(list_1):
#     print(list_1[i])

# %%
# fsf_out_file[:-4]

# %%
# if len(list_1) == len(list_2) and len(list_1) > 1:
#     for i,idx in enumerate(list_1):
#         pattern = list_1[i]
#         info_file = list_2[i]
#         out_tmp = out_file[:-4] + "tmp.txt"
#         if i == 0:
#             out_tmp = reg_ex_sub(in_file=file,info_file=info_file,pattern=pattern,out_file=out_tmp)
#         elif i != len(list_1):
#             out_tmp = reg_ex_sub(in_file=out_tmp,info_file=info_file,pattern=pattern,out_file=out_tmp)
#         else:
#             out_file = reg_ex_sub(in_file=out_tmp,info_file=info_file,pattern=pattern,out_file=out_file)
# elif len(list_1) == len(list_2) and len(list_1) == 1:
#     out_file = reg_ex_sub(in_file=file,info_file=list_2[0],pattern=list_1[0],out_file=out_file)
# elif len(list_1) != len(list_2):
#     print("")
#     print("The number of inputs is not the same length. Exiting.")
#     print("")
#     sys.exit(1)

# %%
def reg_ex_file(file,out_file,list_1,list_2):
    '''
    REgular EXpression FILE is a wrapper function for REgular EXpression SUBstitution.
    
    N.B.: list_1 and list_2 must be the same length. Otherwise, this functions throughs an error.
    
    Arguments:
        file (file): Input file to be searched
        out_file (file): Output file to be written to
        list_1 (list): List of patterns to be matched
        list_2 (list): List of file paths to files that contain text to replace matched patterns.
    Returns:
        out_file (file): Output file with text from info_file replacing the matched pattern in file
    '''
    
    if len(list_1) == len(list_2) and len(list_1) > 1:
        for i,idx in enumerate(list_1):
            pattern = list_1[i]
            info_file = list_2[i]
            # out_tmp = out_file[:-4] + ".tmp.txt"
            out_tmp = out_file
            if i == 0:
                out_tmp = reg_ex_sub(in_file=file,info_file=info_file,pattern=pattern,out_file=out_tmp)
            elif i != len(list_1):
                out_tmp = reg_ex_sub(in_file=out_tmp,info_file=info_file,pattern=pattern,out_file=out_tmp)
            elif i == len(list_1):
                out_file = reg_ex_sub(in_file=out_tmp,info_file=info_file,pattern=pattern,out_file=out_file)
                os.remove(out_tmp)
    elif len(list_1) == len(list_2) and len(list_1) == 1:
        out_file = reg_ex_sub(in_file=file,info_file=list_2[0],pattern=list_1[0],out_file=out_file)
    elif len(list_1) != len(list_2):
        print("")
        print("The number of paired inputs must match. Exiting.")
        print("")
        sys.exit(1) 
    return out_file

# %%
aux_files = ["files.auxillary/out_1.txt" , "files.auxillary/out_2.txt", "files.auxillary/out_3.txt"]

# %%
patterns = ["{sub_data}","{sub_stat_1}","{sub_mem}"]

# %%
reg_ex_file(file=fsf_file,out_file="test.1.fsf",list_1=patterns,list_2=aux_files)
# Out:
# 'test.1.fsf'

# %%
reg_ex_sub(fsf_file,os.getcwd(),"{out_dir}","test.1.fsf")
# Out:
# 'test.1.fsf'

# %%
fsf_out_file = shutil.copy2(fsf_file,fsf_out_file)

# %%
with open(fsf_out_file,"r") as file:
    lines = file.readlines()
    file.close()

# %%
lines
# Out:
# ['\n',
#  '# FEAT version number\n',
#  'set fmri(version) 6.00\n',
#  '\n',
#  '# Are we in MELODIC?\n',
#  'set fmri(inmelodic) 0\n',
#  '\n',
#  '# Analysis level\n',
#  '# 1 : First-level analysis\n',
#  '# 2 : Higher-level analysis\n',
#  'set fmri(level) 2\n',
#  '\n',
#  '# Which stages to run\n',
#  '# 0 : No first-level analysis (registration and/or group stats only)\n',
#  '# 7 : Full first-level analysis\n',
#  '# 1 : Pre-processing\n',
#  '# 2 : Statistics\n',
#  'set fmri(analysis) 2\n',
#  '\n',
#  '# Use relative filenames\n',
#  'set fmri(relative_yn) 0\n',
#  '\n',
#  '# Balloon help\n',
#  'set fmri(help_yn) 1\n',
#  '\n',
#  '# Run Featwatcher\n',
#  'set fmri(featwatcher_yn) 1\n',
#  '\n',
#  '# Cleanup first-level standard-space images\n',
#  'set fmri(sscleanup_yn) 0\n',
#  '\n',
#  '# Output directory\n',
#  'set fmri(outputdir) "{out_dir}"\n',
#  '\n',
#  '# TR(s)\n',
#  'set fmri(tr) 3\n',
#  '\n',
#  '# Total volumes\n',
#  'set fmri(npts) {num_subs}\n',
#  '\n',
#  '# Delete volumes\n',
#  'set fmri(ndelete) 0\n',
#  '\n',
#  '# Perfusion tag/control order\n',
#  'set fmri(tagfirst) 1\n',
#  '\n',
#  '# Number of first-level analyses\n',
#  'set fmri(multiple) {num_subs}\n',
#  '\n',
#  '# Higher-level input type\n',
#  '# 1 : Inputs are lower-level FEAT directories\n',
#  '# 2 : Inputs are cope images from FEAT directories\n',
#  'set fmri(inputtype) 1\n',
#  '\n',
#  '# Carry out pre-stats processing?\n',
#  'set fmri(filtering_yn) 0\n',
#  '\n',
#  '# Brain/background threshold, %\n',
#  'set fmri(brain_thresh) 10\n',
#  '\n',
#  '# Critical z for design efficiency calculation\n',
#  'set fmri(critical_z) 5.3\n',
#  '\n',
#  '# Noise level\n',
#  'set fmri(noise) 0.66\n',
#  '\n',
#  '# Noise AR(1)\n',
#  'set fmri(noisear) 0.34\n',
#  '\n',
#  '# Motion correction\n',
#  '# 0 : None\n',
#  '# 1 : MCFLIRT\n',
#  'set fmri(mc) 1\n',
#  '\n',
#  '# Spin-history (currently obsolete)\n',
#  'set fmri(sh_yn) 0\n',
#  '\n',
#  '# B0 fieldmap unwarping?\n',
#  'set fmri(regunwarp_yn) 0\n',
#  '\n',
#  '# GDC Test\n',
#  'set fmri(gdc) ""\n',
#  '\n',
#  '# EPI dwell time (ms)\n',
#  'set fmri(dwell) 0.0\n',
#  '\n',
#  '# EPI TE (ms)\n',
#  'set fmri(te) 0.0\n',
#  '\n',
#  '# % Signal loss threshold\n',
#  'set fmri(signallossthresh) 10\n',
#  '\n',
#  '# Unwarp direction\n',
#  'set fmri(unwarp_dir) y-\n',
#  '\n',
#  '# Slice timing correction\n',
#  '# 0 : None\n',
#  '# 1 : Regular up (0, 1, 2, 3, ...)\n',
#  '# 2 : Regular down\n',
#  '# 3 : Use slice order file\n',
#  '# 4 : Use slice timings file\n',
#  '# 5 : Interleaved (0, 2, 4 ... 1, 3, 5 ... )\n',
#  'set fmri(st) 0\n',
#  '\n',
#  '# Slice timings file\n',
#  'set fmri(st_file) ""\n',
#  '\n',
#  '# BET brain extraction\n',
#  'set fmri(bet_yn) 1\n',
#  '\n',
#  '# Spatial smoothing FWHM (mm)\n',
#  'set fmri(smooth) 5\n',
#  '\n',
#  '# Intensity normalization\n',
#  'set fmri(norm_yn) 0\n',
#  '\n',
#  '# Perfusion subtraction\n',
#  'set fmri(perfsub_yn) 0\n',
#  '\n',
#  '# Highpass temporal filtering\n',
#  'set fmri(temphp_yn) 1\n',
#  '\n',
#  '# Lowpass temporal filtering\n',
#  'set fmri(templp_yn) 0\n',
#  '\n',
#  '# MELODIC ICA data exploration\n',
#  'set fmri(melodic_yn) 0\n',
#  '\n',
#  '# Carry out main stats?\n',
#  'set fmri(stats_yn) 1\n',
#  '\n',
#  '# Carry out prewhitening?\n',
#  'set fmri(prewhiten_yn) 1\n',
#  '\n',
#  '# Add motion parameters to model\n',
#  '# 0 : No\n',
#  '# 1 : Yes\n',
#  'set fmri(motionevs) 0\n',
#  'set fmri(motionevsbeta) ""\n',
#  'set fmri(scriptevsbeta) ""\n',
#  '\n',
#  '# Robust outlier detection in FLAME?\n',
#  'set fmri(robust_yn) 0\n',
#  '\n',
#  '# Higher-level modelling\n',
#  '# 3 : Fixed effects\n',
#  '# 0 : Mixed Effects: Simple OLS\n',
#  '# 2 : Mixed Effects: FLAME 1\n',
#  '# 1 : Mixed Effects: FLAME 1+2\n',
#  'set fmri(mixed_yn) 3\n',
#  '\n',
#  '# Higher-level permutations\n',
#  'set fmri(randomisePermutations) 5000\n',
#  '\n',
#  '# Number of EVs\n',
#  'set fmri(evs_orig) 3\n',
#  'set fmri(evs_real) 3\n',
#  'set fmri(evs_vox) 0\n',
#  '\n',
#  '# Number of contrasts\n',
#  'set fmri(ncon_orig) 1\n',
#  'set fmri(ncon_real) 3\n',
#  '\n',
#  '# Number of F-tests\n',
#  'set fmri(nftests_orig) 0\n',
#  'set fmri(nftests_real) 0\n',
#  '\n',
#  '# Add constant column to design matrix? (obsolete)\n',
#  'set fmri(constcol) 0\n',
#  '\n',
#  '# Carry out post-stats steps?\n',
#  'set fmri(poststats_yn) 0\n',
#  '\n',
#  '# Pre-threshold masking?\n',
#  'set fmri(threshmask) ""\n',
#  '\n',
#  '# Thresholding\n',
#  '# 0 : None\n',
#  '# 1 : Uncorrected\n',
#  '# 2 : Voxel\n',
#  '# 3 : Cluster\n',
#  'set fmri(thresh) 3\n',
#  '\n',
#  '# P threshold\n',
#  'set fmri(prob_thresh) 0.05\n',
#  '\n',
#  '# Z threshold\n',
#  'set fmri(z_thresh) 3.1\n',
#  '\n',
#  '# Z min/max for colour rendering\n',
#  '# 0 : Use actual Z min/max\n',
#  '# 1 : Use preset Z min/max\n',
#  'set fmri(zdisplay) 0\n',
#  '\n',
#  '# Z min in colour rendering\n',
#  'set fmri(zmin) 2\n',
#  '\n',
#  '# Z max in colour rendering\n',
#  'set fmri(zmax) 8\n',
#  '\n',
#  '# Colour rendering type\n',
#  '# 0 : Solid blobs\n',
#  '# 1 : Transparent blobs\n',
#  'set fmri(rendertype) 1\n',
#  '\n',
#  '# Background image for higher-level stats overlays\n',
#  '# 1 : Mean highres\n',
#  '# 2 : First highres\n',
#  '# 3 : Mean functional\n',
#  '# 4 : First functional\n',
#  '# 5 : Standard space template\n',
#  'set fmri(bgimage) 1\n',
#  '\n',
#  '# Create time series plots\n',
#  'set fmri(tsplot_yn) 1\n',
#  '\n',
#  '# Registration to initial structural\n',
#  'set fmri(reginitial_highres_yn) 0\n',
#  '\n',
#  '# Search space for registration to initial structural\n',
#  '# 0   : No search\n',
#  '# 90  : Normal search\n',
#  '# 180 : Full search\n',
#  'set fmri(reginitial_highres_search) 90\n',
#  '\n',
#  '# Degrees of Freedom for registration to initial structural\n',
#  'set fmri(reginitial_highres_dof) 3\n',
#  '\n',
#  '# Registration to main structural\n',
#  'set fmri(reghighres_yn) 0\n',
#  '\n',
#  '# Search space for registration to main structural\n',
#  '# 0   : No search\n',
#  '# 90  : Normal search\n',
#  '# 180 : Full search\n',
#  'set fmri(reghighres_search) 90\n',
#  '\n',
#  '# Degrees of Freedom for registration to main structural\n',
#  'set fmri(reghighres_dof) BBR\n',
#  '\n',
#  '# Registration to standard image?\n',
#  'set fmri(regstandard_yn) 1\n',
#  '\n',
#  '# Use alternate reference images?\n',
#  'set fmri(alternateReference_yn) 0\n',
#  '\n',
#  '# Standard image\n',
#  'set fmri(regstandard) "/usr/local/fsl/6.0.3/data/standard/MNI152_T1_2mm_brain"\n',
#  '\n',
#  '# Search space for registration to standard space\n',
#  '# 0   : No search\n',
#  '# 90  : Normal search\n',
#  '# 180 : Full search\n',
#  'set fmri(regstandard_search) 90\n',
#  '\n',
#  '# Degrees of Freedom for registration to standard space\n',
#  'set fmri(regstandard_dof) 12\n',
#  '\n',
#  '# Do nonlinear registration from structural to standard space?\n',
#  'set fmri(regstandard_nonlinear_yn) 0\n',
#  '\n',
#  '# Control nonlinear warp field resolution\n',
#  'set fmri(regstandard_nonlinear_warpres) 10 \n',
#  '\n',
#  '# High pass filter cutoff\n',
#  'set fmri(paradigm_hp) 100\n',
#  '\n',
#  '# Number of lower-level copes feeding into higher-level analysis\n',
#  'set fmri(ncopeinputs) 13\n',
#  '\n',
#  '# Use lower-level cope 1 for higher-level analysis\n',
#  'set fmri(copeinput.1) 1\n',
#  '\n',
#  '# Use lower-level cope 2 for higher-level analysis\n',
#  'set fmri(copeinput.2) 1\n',
#  '\n',
#  '# Use lower-level cope 3 for higher-level analysis\n',
#  'set fmri(copeinput.3) 1\n',
#  '\n',
#  '# Use lower-level cope 4 for higher-level analysis\n',
#  'set fmri(copeinput.4) 1\n',
#  '\n',
#  '# Use lower-level cope 5 for higher-level analysis\n',
#  'set fmri(copeinput.5) 1\n',
#  '\n',
#  '# Use lower-level cope 6 for higher-level analysis\n',
#  'set fmri(copeinput.6) 1\n',
#  '\n',
#  '# Use lower-level cope 7 for higher-level analysis\n',
#  'set fmri(copeinput.7) 1\n',
#  '\n',
#  '# Use lower-level cope 8 for higher-level analysis\n',
#  'set fmri(copeinput.8) 1\n',
#  '\n',
#  '# Use lower-level cope 9 for higher-level analysis\n',
#  'set fmri(copeinput.9) 1\n',
#  '\n',
#  '# Use lower-level cope 10 for higher-level analysis\n',
#  'set fmri(copeinput.10) 1\n',
#  '\n',
#  '# Use lower-level cope 11 for higher-level analysis\n',
#  'set fmri(copeinput.11) 1\n',
#  '\n',
#  '# Use lower-level cope 12 for higher-level analysis\n',
#  'set fmri(copeinput.12) 1\n',
#  '\n',
#  '# Use lower-level cope 13 for higher-level analysis\n',
#  'set fmri(copeinput.13) 1\n',
#  '{sub_data}\n',
#  '\n',
#  '# Add confound EVs text file\n',
#  'set fmri(confoundevs) 0\n',
#  '\n',
#  '# EV 1 title\n',
#  'set fmri(evtitle1) "Age"\n',
#  '\n',
#  '# Basic waveform shape (EV 1)\n',
#  '# 0 : Square\n',
#  '# 1 : Sinusoid\n',
#  '# 2 : Custom (1 entry per volume)\n',
#  '# 3 : Custom (3 column format)\n',
#  '# 4 : Interaction\n',
#  '# 10 : Empty (all zeros)\n',
#  'set fmri(shape1) 2\n',
#  '\n',
#  '# Convolution (EV 1)\n',
#  '# 0 : None\n',
#  '# 1 : Gaussian\n',
#  '# 2 : Gamma\n',
#  '# 3 : Double-Gamma HRF\n',
#  '# 4 : Gamma basis functions\n',
#  '# 5 : Sine basis functions\n',
#  '# 6 : FIR basis functions\n',
#  '# 8 : Alternate Double-Gamma\n',
#  'set fmri(convolve1) 0\n',
#  '\n',
#  '# Convolve phase (EV 1)\n',
#  'set fmri(convolve_phase1) 0\n',
#  '\n',
#  '# Apply temporal filtering (EV 1)\n',
#  'set fmri(tempfilt_yn1) 0\n',
#  '\n',
#  '# Add temporal derivative (EV 1)\n',
#  'set fmri(deriv_yn1) 0\n',
#  '\n',
#  '# Custom EV file (EV 1)\n',
#  'set fmri(custom1) "dummy"\n',
#  '\n',
#  '# Orthogonalise EV 1 wrt EV 0\n',
#  'set fmri(ortho1.0) 0\n',
#  '\n',
#  '# Orthogonalise EV 1 wrt EV 1\n',
#  'set fmri(ortho1.1) 0\n',
#  '\n',
#  '# Orthogonalise EV 1 wrt EV 2\n',
#  'set fmri(ortho1.2) 0\n',
#  '\n',
#  '# Orthogonalise EV 1 wrt EV 3\n',
#  'set fmri(ortho1.3) 0\n',
#  '{sub_stat_1}\n',
#  '\n',
#  '# EV 2 title\n',
#  'set fmri(evtitle2) "Gender"\n',
#  '\n',
#  '# Basic waveform shape (EV 2)\n',
#  '# 0 : Square\n',
#  '# 1 : Sinusoid\n',
#  '# 2 : Custom (1 entry per volume)\n',
#  '# 3 : Custom (3 column format)\n',
#  '# 4 : Interaction\n',
#  '# 10 : Empty (all zeros)\n',
#  'set fmri(shape2) 2\n',
#  '\n',
#  '# Convolution (EV 2)\n',
#  '# 0 : None\n',
#  '# 1 : Gaussian\n',
#  '# 2 : Gamma\n',
#  '# 3 : Double-Gamma HRF\n',
#  '# 4 : Gamma basis functions\n',
#  '# 5 : Sine basis functions\n',
#  '# 6 : FIR basis functions\n',
#  '# 8 : Alternate Double-Gamma\n',
#  'set fmri(convolve2) 0\n',
#  '\n',
#  '# Convolve phase (EV 2)\n',
#  'set fmri(convolve_phase2) 0\n',
#  '\n',
#  '# Apply temporal filtering (EV 2)\n',
#  'set fmri(tempfilt_yn2) 0\n',
#  '\n',
#  '# Add temporal derivative (EV 2)\n',
#  'set fmri(deriv_yn2) 0\n',
#  '\n',
#  '# Custom EV file (EV 2)\n',
#  'set fmri(custom2) "dummy"\n',
#  '\n',
#  '# Orthogonalise EV 2 wrt EV 0\n',
#  'set fmri(ortho2.0) 0\n',
#  '\n',
#  '# Orthogonalise EV 2 wrt EV 1\n',
#  'set fmri(ortho2.1) 0\n',
#  '\n',
#  '# Orthogonalise EV 2 wrt EV 2\n',
#  'set fmri(ortho2.2) 0\n',
#  '\n',
#  '# Orthogonalise EV 2 wrt EV 3\n',
#  'set fmri(ortho2.3) 0\n',
#  '{sub_stat_2}\n',
#  '\n',
#  '# EV 3 title\n',
#  'set fmri(evtitle3) "{covariate}"\n',
#  '\n',
#  '# Basic waveform shape (EV 3)\n',
#  '# 0 : Square\n',
#  '# 1 : Sinusoid\n',
#  '# 2 : Custom (1 entry per volume)\n',
#  '# 3 : Custom (3 column format)\n',
#  '# 4 : Interaction\n',
#  '# 10 : Empty (all zeros)\n',
#  'set fmri(shape3) 2\n',
#  '\n',
#  '# Convolution (EV 3)\n',
#  '# 0 : None\n',
#  '# 1 : Gaussian\n',
#  '# 2 : Gamma\n',
#  '# 3 : Double-Gamma HRF\n',
#  '# 4 : Gamma basis functions\n',
#  '# 5 : Sine basis functions\n',
#  '# 6 : FIR basis functions\n',
#  '# 8 : Alternate Double-Gamma\n',
#  'set fmri(convolve3) 0\n',
#  '\n',
#  '# Convolve phase (EV 3)\n',
#  'set fmri(convolve_phase3) 0\n',
#  '\n',
#  '# Apply temporal filtering (EV 3)\n',
#  'set fmri(tempfilt_yn3) 0\n',
#  '\n',
#  '# Add temporal derivative (EV 3)\n',
#  'set fmri(deriv_yn3) 0\n',
#  '\n',
#  '# Custom EV file (EV 3)\n',
#  'set fmri(custom3) "dummy"\n',
#  '\n',
#  '# Orthogonalise EV 3 wrt EV 0\n',
#  'set fmri(ortho3.0) 0\n',
#  '\n',
#  '# Orthogonalise EV 3 wrt EV 1\n',
#  'set fmri(ortho3.1) 0\n',
#  '\n',
#  '# Orthogonalise EV 3 wrt EV 2\n',
#  'set fmri(ortho3.2) 0\n',
#  '\n',
#  '# Orthogonalise EV 3 wrt EV 3\n',
#  'set fmri(ortho3.3) 0\n',
#  '{sub_stat_3}\n',
#  '\n',
#  '# Setup Orthogonalisation at higher level? \n',
#  'set fmri(level2orth) 0\n',
#  '{sub_mem}\n',
#  '\n',
#  '# Contrast & F-tests mode\n',
#  '# real : control real EVs\n',
#  '# orig : control original EVs\n',
#  'set fmri(con_mode_old) real\n',
#  'set fmri(con_mode) real\n',
#  '\n',
#  '# Display images for contrast_real 1\n',
#  'set fmri(conpic_real.1) 1\n',
#  '\n',
#  '# Title for contrast_real 1\n',
#  'set fmri(conname_real.1) "Age"\n',
#  '\n',
#  '# Real contrast_real vector 1 element 1\n',
#  'set fmri(con_real1.1) 1\n',
#  '\n',
#  '# Real contrast_real vector 1 element 2\n',
#  'set fmri(con_real1.2) 0\n',
#  '\n',
#  '# Real contrast_real vector 1 element 3\n',
#  'set fmri(con_real1.3) 0\n',
#  '\n',
#  '# Display images for contrast_real 2\n',
#  'set fmri(conpic_real.2) 1\n',
#  '\n',
#  '# Title for contrast_real 2\n',
#  'set fmri(conname_real.2) "Gender"\n',
#  '\n',
#  '# Real contrast_real vector 2 element 1\n',
#  'set fmri(con_real2.1) 0\n',
#  '\n',
#  '# Real contrast_real vector 2 element 2\n',
#  'set fmri(con_real2.2) 1\n',
#  '\n',
#  '# Real contrast_real vector 2 element 3\n',
#  'set fmri(con_real2.3) 0\n',
#  '\n',
#  '# Display images for contrast_real 3\n',
#  'set fmri(conpic_real.3) 1\n',
#  '\n',
#  '# Title for contrast_real 3\n',
#  'set fmri(conname_real.3) "{covariate}"\n',
#  '\n',
#  '# Real contrast_real vector 3 element 1\n',
#  'set fmri(con_real3.1) 0\n',
#  '\n',
#  '# Real contrast_real vector 3 element 2\n',
#  'set fmri(con_real3.2) 0\n',
#  '\n',
#  '# Real contrast_real vector 3 element 3\n',
#  'set fmri(con_real3.3) 1\n',
#  '\n',
#  '# Contrast masking - use >0 instead of thresholding?\n',
#  'set fmri(conmask_zerothresh_yn) 0\n',
#  '\n',
#  '# Mask real contrast/F-test 1 with real contrast/F-test 2?\n',
#  'set fmri(conmask1_2) 0\n',
#  '\n',
#  '# Mask real contrast/F-test 1 with real contrast/F-test 3?\n',
#  'set fmri(conmask1_3) 0\n',
#  '\n',
#  '# Mask real contrast/F-test 2 with real contrast/F-test 1?\n',
#  'set fmri(conmask2_1) 0\n',
#  '\n',
#  '# Mask real contrast/F-test 2 with real contrast/F-test 3?\n',
#  'set fmri(conmask2_3) 0\n',
#  '\n',
#  '# Mask real contrast/F-test 3 with real contrast/F-test 1?\n',
#  'set fmri(conmask3_1) 0\n',
#  '\n',
#  '# Mask real contrast/F-test 3 with real contrast/F-test 2?\n',
#  'set fmri(conmask3_2) 0\n',
#  '\n',
#  '# Do contrast masking at all?\n',
#  'set fmri(conmask1_1) 0\n',
#  '\n',
#  '##########################################################\n',
#  "# Now options that don't appear in the GUI\n",
#  '\n',
#  '# Alternative (to BETting) mask image\n',
#  'set fmri(alternative_mask) ""\n',
#  '\n',
#  '# Initial structural space registration initialisation transform\n',
#  'set fmri(init_initial_highres) ""\n',
#  '\n',
#  '# Structural space registration initialisation transform\n',
#  'set fmri(init_highres) ""\n',
#  '\n',
#  '# Standard space registration initialisation transform\n',
#  'set fmri(init_standard) ""\n',
#  '\n',
#  '# For full FEAT analysis: overwrite existing .feat output dir?\n',
#  'set fmri(overwrite_yn) 0\n']

# %%
# file.close()

# %%
regexp = re.compile(r'\{sub_data\}')

# %%
with open(fsf_out_file,"r") as f:
    for line in f:
        match = regexp.match(line)
        if match:
            print(match.group())
# Out:
# {sub_data}

# %%
# Out:
# NoneType

# %%
def read_file(file):
    '''
    Opens the (text) file, reads its contents, and stores those contents in a list of strings.
    
    Arguments:
        file (file): Input file
    Returns:
        lines (list): List of strings of the file contents
    '''
    
    with open(file,"r") as file:
        lines = file.readlines()
        file.close()
    return lines

# %%
info = read_file(file=info_file)

# %%
len(info)
# Out:
# 324

# %%
info
# Out:
# ['\n',
#  '# 4D AVW data or FEAT directory (1)\n',
#  'set feat_files(1) "/scratch/brac4g/HONESTY/bart_data/sub-001/001-001_bart/001-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (2)\n',
#  'set feat_files(2) "/scratch/brac4g/HONESTY/bart_data/sub-003/003-001_bart/003-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (3)\n',
#  'set feat_files(3) "/scratch/brac4g/HONESTY/bart_data/sub-004/004-001_bart/004-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (4)\n',
#  'set feat_files(4) "/scratch/brac4g/HONESTY/bart_data/sub-006/006-001_bart/006-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (5)\n',
#  'set feat_files(5) "/scratch/brac4g/HONESTY/bart_data/sub-007/007-001_bart/007-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (6)\n',
#  'set feat_files(6) "/scratch/brac4g/HONESTY/bart_data/sub-008/008-001_bart/008-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (7)\n',
#  'set feat_files(7) "/scratch/brac4g/HONESTY/bart_data/sub-010/010-001_bart/010-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (8)\n',
#  'set feat_files(8) "/scratch/brac4g/HONESTY/bart_data/sub-011/011-001_bart/011-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (9)\n',
#  'set feat_files(9) "/scratch/brac4g/HONESTY/bart_data/sub-013/013-001_bart/013-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (10)\n',
#  'set feat_files(10) "/scratch/brac4g/HONESTY/bart_data/sub-014/014-001_bart/014-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (11)\n',
#  'set feat_files(11) "/scratch/brac4g/HONESTY/bart_data/sub-015/015-001_bart/015-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (12)\n',
#  'set feat_files(12) "/scratch/brac4g/HONESTY/bart_data/sub-016/016-001_bart/016-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (13)\n',
#  'set feat_files(13) "/scratch/brac4g/HONESTY/bart_data/sub-017/017-001_bart/017-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (14)\n',
#  'set feat_files(14) "/scratch/brac4g/HONESTY/bart_data/sub-018/018-001_bart/018-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (15)\n',
#  'set feat_files(15) "/scratch/brac4g/HONESTY/bart_data/sub-019/019-001_bart/019-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (16)\n',
#  'set feat_files(16) "/scratch/brac4g/HONESTY/bart_data/sub-020/020-001_bart/020-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (17)\n',
#  'set feat_files(17) "/scratch/brac4g/HONESTY/bart_data/sub-022/022-001_bart/022-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (18)\n',
#  'set feat_files(18) "/scratch/brac4g/HONESTY/bart_data/sub-023/023-001_bart/023-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (19)\n',
#  'set feat_files(19) "/scratch/brac4g/HONESTY/bart_data/sub-024/024-001_bart/024-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (20)\n',
#  'set feat_files(20) "/scratch/brac4g/HONESTY/bart_data/sub-025/025-001_bart/025-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (21)\n',
#  'set feat_files(21) "/scratch/brac4g/HONESTY/bart_data/sub-026/026-001_bart/026-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (22)\n',
#  'set feat_files(22) "/scratch/brac4g/HONESTY/bart_data/sub-027/027-001_bart/027-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (23)\n',
#  'set feat_files(23) "/scratch/brac4g/HONESTY/bart_data/sub-028/028-001_bart/028-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (24)\n',
#  'set feat_files(24) "/scratch/brac4g/HONESTY/bart_data/sub-029/029-001_bart/029-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (25)\n',
#  'set feat_files(25) "/scratch/brac4g/HONESTY/bart_data/sub-030/030-001_bart/030-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (26)\n',
#  'set feat_files(26) "/scratch/brac4g/HONESTY/bart_data/sub-031/031-001_bart/031-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (27)\n',
#  'set feat_files(27) "/scratch/brac4g/HONESTY/bart_data/sub-033/033-001_bart/033-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (28)\n',
#  'set feat_files(28) "/scratch/brac4g/HONESTY/bart_data/sub-034/034-001_bart/034-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (29)\n',
#  'set feat_files(29) "/scratch/brac4g/HONESTY/bart_data/sub-035/035-001_bart/035-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (30)\n',
#  'set feat_files(30) "/scratch/brac4g/HONESTY/bart_data/sub-036/036-001_bart/036-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (31)\n',
#  'set feat_files(31) "/scratch/brac4g/HONESTY/bart_data/sub-037/037-001_bart/037-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (32)\n',
#  'set feat_files(32) "/scratch/brac4g/HONESTY/bart_data/sub-038/038-001_bart/038-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (33)\n',
#  'set feat_files(33) "/scratch/brac4g/HONESTY/bart_data/sub-040/040-001_bart/040-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (34)\n',
#  'set feat_files(34) "/scratch/brac4g/HONESTY/bart_data/sub-041/041-001_bart/041-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (35)\n',
#  'set feat_files(35) "/scratch/brac4g/HONESTY/bart_data/sub-042/042-001_bart/042-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (36)\n',
#  'set feat_files(36) "/scratch/brac4g/HONESTY/bart_data/sub-043/043-001_bart/043-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (37)\n',
#  'set feat_files(37) "/scratch/brac4g/HONESTY/bart_data/sub-044/044-001_bart/044-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (38)\n',
#  'set feat_files(38) "/scratch/brac4g/HONESTY/bart_data/sub-045/045-001_bart/045-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (39)\n',
#  'set feat_files(39) "/scratch/brac4g/HONESTY/bart_data/sub-047/047-001_bart/047-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (40)\n',
#  'set feat_files(40) "/scratch/brac4g/HONESTY/bart_data/sub-048/048-001_bart/048-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (41)\n',
#  'set feat_files(41) "/scratch/brac4g/HONESTY/bart_data/sub-049/049-001_bart/049-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (42)\n',
#  'set feat_files(42) "/scratch/brac4g/HONESTY/bart_data/sub-050/050-001_bart/050-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (43)\n',
#  'set feat_files(43) "/scratch/brac4g/HONESTY/bart_data/sub-051/051-001_bart/051-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (44)\n',
#  'set feat_files(44) "/scratch/brac4g/HONESTY/bart_data/sub-054/054-001_bart/054-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (45)\n',
#  'set feat_files(45) "/scratch/brac4g/HONESTY/bart_data/sub-055/055-001_bart/055-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (46)\n',
#  'set feat_files(46) "/scratch/brac4g/HONESTY/bart_data/sub-057/057-001_bart/057-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (47)\n',
#  'set feat_files(47) "/scratch/brac4g/HONESTY/bart_data/sub-058/058-001_bart/058-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (48)\n',
#  'set feat_files(48) "/scratch/brac4g/HONESTY/bart_data/sub-059/059-001_bart/059-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (49)\n',
#  'set feat_files(49) "/scratch/brac4g/HONESTY/bart_data/sub-060/060-001_bart/060-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (50)\n',
#  'set feat_files(50) "/scratch/brac4g/HONESTY/bart_data/sub-061/061-001_bart/061-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (51)\n',
#  'set feat_files(51) "/scratch/brac4g/HONESTY/bart_data/sub-062/062-001_bart/062-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (52)\n',
#  'set feat_files(52) "/scratch/brac4g/HONESTY/bart_data/sub-063/063-001_bart/063-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (53)\n',
#  'set feat_files(53) "/scratch/brac4g/HONESTY/bart_data/sub-064/064-001_bart/064-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (54)\n',
#  'set feat_files(54) "/scratch/brac4g/HONESTY/bart_data/sub-065/065-001_bart/065-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (55)\n',
#  'set feat_files(55) "/scratch/brac4g/HONESTY/bart_data/sub-066/066-001_bart/066-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (56)\n',
#  'set feat_files(56) "/scratch/brac4g/HONESTY/bart_data/sub-067/067-001_bart/067-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (57)\n',
#  'set feat_files(57) "/scratch/brac4g/HONESTY/bart_data/sub-068/068-001_bart/068-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (58)\n',
#  'set feat_files(58) "/scratch/brac4g/HONESTY/bart_data/sub-069/069-001_bart/069-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (59)\n',
#  'set feat_files(59) "/scratch/brac4g/HONESTY/bart_data/sub-070/070-001_bart/070-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (60)\n',
#  'set feat_files(60) "/scratch/brac4g/HONESTY/bart_data/sub-071/071-001_bart/071-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (61)\n',
#  'set feat_files(61) "/scratch/brac4g/HONESTY/bart_data/sub-073/073-001_bart/073-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (62)\n',
#  'set feat_files(62) "/scratch/brac4g/HONESTY/bart_data/sub-074/074-001_bart/074-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (63)\n',
#  'set feat_files(63) "/scratch/brac4g/HONESTY/bart_data/sub-077/077-001_bart/077-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (64)\n',
#  'set feat_files(64) "/scratch/brac4g/HONESTY/bart_data/sub-078/078-001_bart/078-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (65)\n',
#  'set feat_files(65) "/scratch/brac4g/HONESTY/bart_data/sub-079/079-001_bart/079-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (66)\n',
#  'set feat_files(66) "/scratch/brac4g/HONESTY/bart_data/sub-080/080-001_bart/080-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (67)\n',
#  'set feat_files(67) "/scratch/brac4g/HONESTY/bart_data/sub-081/081-001_bart/081-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (68)\n',
#  'set feat_files(68) "/scratch/brac4g/HONESTY/bart_data/sub-082/082-001_bart/082-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (69)\n',
#  'set feat_files(69) "/scratch/brac4g/HONESTY/bart_data/sub-083/083-001_bart/083-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (70)\n',
#  'set feat_files(70) "/scratch/brac4g/HONESTY/bart_data/sub-084/084-001_bart/084-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (71)\n',
#  'set feat_files(71) "/scratch/brac4g/HONESTY/bart_data/sub-085/085-001_bart/085-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (72)\n',
#  'set feat_files(72) "/scratch/brac4g/HONESTY/bart_data/sub-086/086-001_bart/086-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (73)\n',
#  'set feat_files(73) "/scratch/brac4g/HONESTY/bart_data/sub-087/087-001_bart/087-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (74)\n',
#  'set feat_files(74) "/scratch/brac4g/HONESTY/bart_data/sub-088/088-001_bart/088-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (75)\n',
#  'set feat_files(75) "/scratch/brac4g/HONESTY/bart_data/sub-089/089-001_bart/089-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (76)\n',
#  'set feat_files(76) "/scratch/brac4g/HONESTY/bart_data/sub-090/090-001_bart/090-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (77)\n',
#  'set feat_files(77) "/scratch/brac4g/HONESTY/bart_data/sub-091/091-001_bart/091-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (78)\n',
#  'set feat_files(78) "/scratch/brac4g/HONESTY/bart_data/sub-092/092-001_bart/092-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (79)\n',
#  'set feat_files(79) "/scratch/brac4g/HONESTY/bart_data/sub-093/093-001_bart/093-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (80)\n',
#  'set feat_files(80) "/scratch/brac4g/HONESTY/bart_data/sub-094/094-001_bart/094-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (81)\n',
#  'set feat_files(81) "/scratch/brac4g/HONESTY/bart_data/sub-095/095-001_bart/095-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (82)\n',
#  'set feat_files(82) "/scratch/brac4g/HONESTY/bart_data/sub-096/096-001_bart/096-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (83)\n',
#  'set feat_files(83) "/scratch/brac4g/HONESTY/bart_data/sub-097/097-001_bart/097-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (84)\n',
#  'set feat_files(84) "/scratch/brac4g/HONESTY/bart_data/sub-098/098-001_bart/098-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (85)\n',
#  'set feat_files(85) "/scratch/brac4g/HONESTY/bart_data/sub-100/100-001_bart/100-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (86)\n',
#  'set feat_files(86) "/scratch/brac4g/HONESTY/bart_data/sub-101/101-001_bart/101-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (87)\n',
#  'set feat_files(87) "/scratch/brac4g/HONESTY/bart_data/sub-102/102-001_bart/102-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (88)\n',
#  'set feat_files(88) "/scratch/brac4g/HONESTY/bart_data/sub-104/104-001_bart/104-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (89)\n',
#  'set feat_files(89) "/scratch/brac4g/HONESTY/bart_data/sub-106/106-001_bart/106-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (90)\n',
#  'set feat_files(90) "/scratch/brac4g/HONESTY/bart_data/sub-107/107-001_bart/107-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (91)\n',
#  'set feat_files(91) "/scratch/brac4g/HONESTY/bart_data/sub-108/108-001_bart/108-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (92)\n',
#  'set feat_files(92) "/scratch/brac4g/HONESTY/bart_data/sub-109/109-001_bart/109-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (93)\n',
#  'set feat_files(93) "/scratch/brac4g/HONESTY/bart_data/sub-110/110-001_bart/110-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (94)\n',
#  'set feat_files(94) "/scratch/brac4g/HONESTY/bart_data/sub-111/111-001_bart/111-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (95)\n',
#  'set feat_files(95) "/scratch/brac4g/HONESTY/bart_data/sub-112/112-001_bart/112-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (96)\n',
#  'set feat_files(96) "/scratch/brac4g/HONESTY/bart_data/sub-113/113-001_bart/113-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (97)\n',
#  'set feat_files(97) "/scratch/brac4g/HONESTY/bart_data/sub-114/114-001_bart/114-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (98)\n',
#  'set feat_files(98) "/scratch/brac4g/HONESTY/bart_data/sub-115/115-001_bart/115-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (99)\n',
#  'set feat_files(99) "/scratch/brac4g/HONESTY/bart_data/sub-116/116-001_bart/116-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (100)\n',
#  'set feat_files(100) "/scratch/brac4g/HONESTY/bart_data/sub-117/117-001_bart/117-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (101)\n',
#  'set feat_files(101) "/scratch/brac4g/HONESTY/bart_data/sub-119/119-001_bart/119-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (102)\n',
#  'set feat_files(102) "/scratch/brac4g/HONESTY/bart_data/sub-120/120-001_bart/120-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (103)\n',
#  'set feat_files(103) "/scratch/brac4g/HONESTY/bart_data/sub-121/121-001_bart/121-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (104)\n',
#  'set feat_files(104) "/scratch/brac4g/HONESTY/bart_data/sub-122/122-001_bart/122-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (105)\n',
#  'set feat_files(105) "/scratch/brac4g/HONESTY/bart_data/sub-123/123-001_bart/123-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (106)\n',
#  'set feat_files(106) "/scratch/brac4g/HONESTY/bart_data/sub-125/125-001_bart/125-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (107)\n',
#  'set feat_files(107) "/scratch/brac4g/HONESTY/bart_data/sub-129/129-001_bart/129-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (108)\n',
#  'set feat_files(108) "/scratch/brac4g/HONESTY/bart_data/sub-131/131-001_bart/131-001_bart.feat"\n']

# %%
pattern = "{out_dir}"

# %%
# regexp = re.compile(r'\{sub_data\}')
regexp = re.compile(f"{pattern}")
new_lines = list()
with open(fsf_file,"r") as f:
    for line in f:
        match = regexp.match(line)
        if match:
            # print(match.group())
            # print(type(match.group()))
            # line_sub_1 = regexp.sub(str(info),match.group())
            # line_sub = line.replace(r'\{sub_data\}',line_sub_1)
            new_lines.extend(info)
            # print(line)
        else:
            new_lines.append(line)
    f.close()

# %%
pattern = "{out_dir}"
# pattern = "{sub_data}"
regexp = re.compile(f"(.*?|\s){pattern}(.*?|\s)")
new_lines = list()
with open(fsf_file,"r") as f:
    for line in f:
        match = regexp.match(line)
        if match:
            print(match.group())
# Out:
# set fmri(outputdir) "{out_dir}

# %%
s = "get to the choppa, NOW!!"
ss = "get"

# %%
regexp = re.compile(f"{ss}")

# %%
regexp.sub("find",s)
# Out:
# 'find to the choppa, NOW!!'

# %%
s
# Out:
# 'get to the choppa, NOW!!'

# %%
# line_sub = re.sub(r'\{sub_data\}',str(info),str(lines))
# line_sub
new_lines
# Out:
# ['\n',
#  '# FEAT version number\n',
#  'set fmri(version) 6.00\n',
#  '\n',
#  '# Are we in MELODIC?\n',
#  'set fmri(inmelodic) 0\n',
#  '\n',
#  '# Analysis level\n',
#  '# 1 : First-level analysis\n',
#  '# 2 : Higher-level analysis\n',
#  'set fmri(level) 2\n',
#  '\n',
#  '# Which stages to run\n',
#  '# 0 : No first-level analysis (registration and/or group stats only)\n',
#  '# 7 : Full first-level analysis\n',
#  '# 1 : Pre-processing\n',
#  '# 2 : Statistics\n',
#  'set fmri(analysis) 2\n',
#  '\n',
#  '# Use relative filenames\n',
#  'set fmri(relative_yn) 0\n',
#  '\n',
#  '# Balloon help\n',
#  'set fmri(help_yn) 1\n',
#  '\n',
#  '# Run Featwatcher\n',
#  'set fmri(featwatcher_yn) 1\n',
#  '\n',
#  '# Cleanup first-level standard-space images\n',
#  'set fmri(sscleanup_yn) 0\n',
#  '\n',
#  '# Output directory\n',
#  'set fmri(outputdir) "{out_dir}"\n',
#  '\n',
#  '# TR(s)\n',
#  'set fmri(tr) 3\n',
#  '\n',
#  '# Total volumes\n',
#  'set fmri(npts) {num_subs}\n',
#  '\n',
#  '# Delete volumes\n',
#  'set fmri(ndelete) 0\n',
#  '\n',
#  '# Perfusion tag/control order\n',
#  'set fmri(tagfirst) 1\n',
#  '\n',
#  '# Number of first-level analyses\n',
#  'set fmri(multiple) {num_subs}\n',
#  '\n',
#  '# Higher-level input type\n',
#  '# 1 : Inputs are lower-level FEAT directories\n',
#  '# 2 : Inputs are cope images from FEAT directories\n',
#  'set fmri(inputtype) 1\n',
#  '\n',
#  '# Carry out pre-stats processing?\n',
#  'set fmri(filtering_yn) 0\n',
#  '\n',
#  '# Brain/background threshold, %\n',
#  'set fmri(brain_thresh) 10\n',
#  '\n',
#  '# Critical z for design efficiency calculation\n',
#  'set fmri(critical_z) 5.3\n',
#  '\n',
#  '# Noise level\n',
#  'set fmri(noise) 0.66\n',
#  '\n',
#  '# Noise AR(1)\n',
#  'set fmri(noisear) 0.34\n',
#  '\n',
#  '# Motion correction\n',
#  '# 0 : None\n',
#  '# 1 : MCFLIRT\n',
#  'set fmri(mc) 1\n',
#  '\n',
#  '# Spin-history (currently obsolete)\n',
#  'set fmri(sh_yn) 0\n',
#  '\n',
#  '# B0 fieldmap unwarping?\n',
#  'set fmri(regunwarp_yn) 0\n',
#  '\n',
#  '# GDC Test\n',
#  'set fmri(gdc) ""\n',
#  '\n',
#  '# EPI dwell time (ms)\n',
#  'set fmri(dwell) 0.0\n',
#  '\n',
#  '# EPI TE (ms)\n',
#  'set fmri(te) 0.0\n',
#  '\n',
#  '# % Signal loss threshold\n',
#  'set fmri(signallossthresh) 10\n',
#  '\n',
#  '# Unwarp direction\n',
#  'set fmri(unwarp_dir) y-\n',
#  '\n',
#  '# Slice timing correction\n',
#  '# 0 : None\n',
#  '# 1 : Regular up (0, 1, 2, 3, ...)\n',
#  '# 2 : Regular down\n',
#  '# 3 : Use slice order file\n',
#  '# 4 : Use slice timings file\n',
#  '# 5 : Interleaved (0, 2, 4 ... 1, 3, 5 ... )\n',
#  'set fmri(st) 0\n',
#  '\n',
#  '# Slice timings file\n',
#  'set fmri(st_file) ""\n',
#  '\n',
#  '# BET brain extraction\n',
#  'set fmri(bet_yn) 1\n',
#  '\n',
#  '# Spatial smoothing FWHM (mm)\n',
#  'set fmri(smooth) 5\n',
#  '\n',
#  '# Intensity normalization\n',
#  'set fmri(norm_yn) 0\n',
#  '\n',
#  '# Perfusion subtraction\n',
#  'set fmri(perfsub_yn) 0\n',
#  '\n',
#  '# Highpass temporal filtering\n',
#  'set fmri(temphp_yn) 1\n',
#  '\n',
#  '# Lowpass temporal filtering\n',
#  'set fmri(templp_yn) 0\n',
#  '\n',
#  '# MELODIC ICA data exploration\n',
#  'set fmri(melodic_yn) 0\n',
#  '\n',
#  '# Carry out main stats?\n',
#  'set fmri(stats_yn) 1\n',
#  '\n',
#  '# Carry out prewhitening?\n',
#  'set fmri(prewhiten_yn) 1\n',
#  '\n',
#  '# Add motion parameters to model\n',
#  '# 0 : No\n',
#  '# 1 : Yes\n',
#  'set fmri(motionevs) 0\n',
#  'set fmri(motionevsbeta) ""\n',
#  'set fmri(scriptevsbeta) ""\n',
#  '\n',
#  '# Robust outlier detection in FLAME?\n',
#  'set fmri(robust_yn) 0\n',
#  '\n',
#  '# Higher-level modelling\n',
#  '# 3 : Fixed effects\n',
#  '# 0 : Mixed Effects: Simple OLS\n',
#  '# 2 : Mixed Effects: FLAME 1\n',
#  '# 1 : Mixed Effects: FLAME 1+2\n',
#  'set fmri(mixed_yn) 3\n',
#  '\n',
#  '# Higher-level permutations\n',
#  'set fmri(randomisePermutations) 5000\n',
#  '\n',
#  '# Number of EVs\n',
#  'set fmri(evs_orig) 3\n',
#  'set fmri(evs_real) 3\n',
#  'set fmri(evs_vox) 0\n',
#  '\n',
#  '# Number of contrasts\n',
#  'set fmri(ncon_orig) 1\n',
#  'set fmri(ncon_real) 3\n',
#  '\n',
#  '# Number of F-tests\n',
#  'set fmri(nftests_orig) 0\n',
#  'set fmri(nftests_real) 0\n',
#  '\n',
#  '# Add constant column to design matrix? (obsolete)\n',
#  'set fmri(constcol) 0\n',
#  '\n',
#  '# Carry out post-stats steps?\n',
#  'set fmri(poststats_yn) 0\n',
#  '\n',
#  '# Pre-threshold masking?\n',
#  'set fmri(threshmask) ""\n',
#  '\n',
#  '# Thresholding\n',
#  '# 0 : None\n',
#  '# 1 : Uncorrected\n',
#  '# 2 : Voxel\n',
#  '# 3 : Cluster\n',
#  'set fmri(thresh) 3\n',
#  '\n',
#  '# P threshold\n',
#  'set fmri(prob_thresh) 0.05\n',
#  '\n',
#  '# Z threshold\n',
#  'set fmri(z_thresh) 3.1\n',
#  '\n',
#  '# Z min/max for colour rendering\n',
#  '# 0 : Use actual Z min/max\n',
#  '# 1 : Use preset Z min/max\n',
#  'set fmri(zdisplay) 0\n',
#  '\n',
#  '# Z min in colour rendering\n',
#  'set fmri(zmin) 2\n',
#  '\n',
#  '# Z max in colour rendering\n',
#  'set fmri(zmax) 8\n',
#  '\n',
#  '# Colour rendering type\n',
#  '# 0 : Solid blobs\n',
#  '# 1 : Transparent blobs\n',
#  'set fmri(rendertype) 1\n',
#  '\n',
#  '# Background image for higher-level stats overlays\n',
#  '# 1 : Mean highres\n',
#  '# 2 : First highres\n',
#  '# 3 : Mean functional\n',
#  '# 4 : First functional\n',
#  '# 5 : Standard space template\n',
#  'set fmri(bgimage) 1\n',
#  '\n',
#  '# Create time series plots\n',
#  'set fmri(tsplot_yn) 1\n',
#  '\n',
#  '# Registration to initial structural\n',
#  'set fmri(reginitial_highres_yn) 0\n',
#  '\n',
#  '# Search space for registration to initial structural\n',
#  '# 0   : No search\n',
#  '# 90  : Normal search\n',
#  '# 180 : Full search\n',
#  'set fmri(reginitial_highres_search) 90\n',
#  '\n',
#  '# Degrees of Freedom for registration to initial structural\n',
#  'set fmri(reginitial_highres_dof) 3\n',
#  '\n',
#  '# Registration to main structural\n',
#  'set fmri(reghighres_yn) 0\n',
#  '\n',
#  '# Search space for registration to main structural\n',
#  '# 0   : No search\n',
#  '# 90  : Normal search\n',
#  '# 180 : Full search\n',
#  'set fmri(reghighres_search) 90\n',
#  '\n',
#  '# Degrees of Freedom for registration to main structural\n',
#  'set fmri(reghighres_dof) BBR\n',
#  '\n',
#  '# Registration to standard image?\n',
#  'set fmri(regstandard_yn) 1\n',
#  '\n',
#  '# Use alternate reference images?\n',
#  'set fmri(alternateReference_yn) 0\n',
#  '\n',
#  '# Standard image\n',
#  'set fmri(regstandard) "/usr/local/fsl/6.0.3/data/standard/MNI152_T1_2mm_brain"\n',
#  '\n',
#  '# Search space for registration to standard space\n',
#  '# 0   : No search\n',
#  '# 90  : Normal search\n',
#  '# 180 : Full search\n',
#  'set fmri(regstandard_search) 90\n',
#  '\n',
#  '# Degrees of Freedom for registration to standard space\n',
#  'set fmri(regstandard_dof) 12\n',
#  '\n',
#  '# Do nonlinear registration from structural to standard space?\n',
#  'set fmri(regstandard_nonlinear_yn) 0\n',
#  '\n',
#  '# Control nonlinear warp field resolution\n',
#  'set fmri(regstandard_nonlinear_warpres) 10 \n',
#  '\n',
#  '# High pass filter cutoff\n',
#  'set fmri(paradigm_hp) 100\n',
#  '\n',
#  '# Number of lower-level copes feeding into higher-level analysis\n',
#  'set fmri(ncopeinputs) 13\n',
#  '\n',
#  '# Use lower-level cope 1 for higher-level analysis\n',
#  'set fmri(copeinput.1) 1\n',
#  '\n',
#  '# Use lower-level cope 2 for higher-level analysis\n',
#  'set fmri(copeinput.2) 1\n',
#  '\n',
#  '# Use lower-level cope 3 for higher-level analysis\n',
#  'set fmri(copeinput.3) 1\n',
#  '\n',
#  '# Use lower-level cope 4 for higher-level analysis\n',
#  'set fmri(copeinput.4) 1\n',
#  '\n',
#  '# Use lower-level cope 5 for higher-level analysis\n',
#  'set fmri(copeinput.5) 1\n',
#  '\n',
#  '# Use lower-level cope 6 for higher-level analysis\n',
#  'set fmri(copeinput.6) 1\n',
#  '\n',
#  '# Use lower-level cope 7 for higher-level analysis\n',
#  'set fmri(copeinput.7) 1\n',
#  '\n',
#  '# Use lower-level cope 8 for higher-level analysis\n',
#  'set fmri(copeinput.8) 1\n',
#  '\n',
#  '# Use lower-level cope 9 for higher-level analysis\n',
#  'set fmri(copeinput.9) 1\n',
#  '\n',
#  '# Use lower-level cope 10 for higher-level analysis\n',
#  'set fmri(copeinput.10) 1\n',
#  '\n',
#  '# Use lower-level cope 11 for higher-level analysis\n',
#  'set fmri(copeinput.11) 1\n',
#  '\n',
#  '# Use lower-level cope 12 for higher-level analysis\n',
#  'set fmri(copeinput.12) 1\n',
#  '\n',
#  '# Use lower-level cope 13 for higher-level analysis\n',
#  'set fmri(copeinput.13) 1\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (1)\n',
#  'set feat_files(1) "/scratch/brac4g/HONESTY/bart_data/sub-001/001-001_bart/001-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (2)\n',
#  'set feat_files(2) "/scratch/brac4g/HONESTY/bart_data/sub-003/003-001_bart/003-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (3)\n',
#  'set feat_files(3) "/scratch/brac4g/HONESTY/bart_data/sub-004/004-001_bart/004-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (4)\n',
#  'set feat_files(4) "/scratch/brac4g/HONESTY/bart_data/sub-006/006-001_bart/006-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (5)\n',
#  'set feat_files(5) "/scratch/brac4g/HONESTY/bart_data/sub-007/007-001_bart/007-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (6)\n',
#  'set feat_files(6) "/scratch/brac4g/HONESTY/bart_data/sub-008/008-001_bart/008-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (7)\n',
#  'set feat_files(7) "/scratch/brac4g/HONESTY/bart_data/sub-010/010-001_bart/010-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (8)\n',
#  'set feat_files(8) "/scratch/brac4g/HONESTY/bart_data/sub-011/011-001_bart/011-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (9)\n',
#  'set feat_files(9) "/scratch/brac4g/HONESTY/bart_data/sub-013/013-001_bart/013-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (10)\n',
#  'set feat_files(10) "/scratch/brac4g/HONESTY/bart_data/sub-014/014-001_bart/014-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (11)\n',
#  'set feat_files(11) "/scratch/brac4g/HONESTY/bart_data/sub-015/015-001_bart/015-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (12)\n',
#  'set feat_files(12) "/scratch/brac4g/HONESTY/bart_data/sub-016/016-001_bart/016-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (13)\n',
#  'set feat_files(13) "/scratch/brac4g/HONESTY/bart_data/sub-017/017-001_bart/017-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (14)\n',
#  'set feat_files(14) "/scratch/brac4g/HONESTY/bart_data/sub-018/018-001_bart/018-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (15)\n',
#  'set feat_files(15) "/scratch/brac4g/HONESTY/bart_data/sub-019/019-001_bart/019-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (16)\n',
#  'set feat_files(16) "/scratch/brac4g/HONESTY/bart_data/sub-020/020-001_bart/020-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (17)\n',
#  'set feat_files(17) "/scratch/brac4g/HONESTY/bart_data/sub-022/022-001_bart/022-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (18)\n',
#  'set feat_files(18) "/scratch/brac4g/HONESTY/bart_data/sub-023/023-001_bart/023-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (19)\n',
#  'set feat_files(19) "/scratch/brac4g/HONESTY/bart_data/sub-024/024-001_bart/024-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (20)\n',
#  'set feat_files(20) "/scratch/brac4g/HONESTY/bart_data/sub-025/025-001_bart/025-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (21)\n',
#  'set feat_files(21) "/scratch/brac4g/HONESTY/bart_data/sub-026/026-001_bart/026-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (22)\n',
#  'set feat_files(22) "/scratch/brac4g/HONESTY/bart_data/sub-027/027-001_bart/027-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (23)\n',
#  'set feat_files(23) "/scratch/brac4g/HONESTY/bart_data/sub-028/028-001_bart/028-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (24)\n',
#  'set feat_files(24) "/scratch/brac4g/HONESTY/bart_data/sub-029/029-001_bart/029-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (25)\n',
#  'set feat_files(25) "/scratch/brac4g/HONESTY/bart_data/sub-030/030-001_bart/030-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (26)\n',
#  'set feat_files(26) "/scratch/brac4g/HONESTY/bart_data/sub-031/031-001_bart/031-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (27)\n',
#  'set feat_files(27) "/scratch/brac4g/HONESTY/bart_data/sub-033/033-001_bart/033-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (28)\n',
#  'set feat_files(28) "/scratch/brac4g/HONESTY/bart_data/sub-034/034-001_bart/034-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (29)\n',
#  'set feat_files(29) "/scratch/brac4g/HONESTY/bart_data/sub-035/035-001_bart/035-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (30)\n',
#  'set feat_files(30) "/scratch/brac4g/HONESTY/bart_data/sub-036/036-001_bart/036-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (31)\n',
#  'set feat_files(31) "/scratch/brac4g/HONESTY/bart_data/sub-037/037-001_bart/037-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (32)\n',
#  'set feat_files(32) "/scratch/brac4g/HONESTY/bart_data/sub-038/038-001_bart/038-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (33)\n',
#  'set feat_files(33) "/scratch/brac4g/HONESTY/bart_data/sub-040/040-001_bart/040-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (34)\n',
#  'set feat_files(34) "/scratch/brac4g/HONESTY/bart_data/sub-041/041-001_bart/041-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (35)\n',
#  'set feat_files(35) "/scratch/brac4g/HONESTY/bart_data/sub-042/042-001_bart/042-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (36)\n',
#  'set feat_files(36) "/scratch/brac4g/HONESTY/bart_data/sub-043/043-001_bart/043-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (37)\n',
#  'set feat_files(37) "/scratch/brac4g/HONESTY/bart_data/sub-044/044-001_bart/044-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (38)\n',
#  'set feat_files(38) "/scratch/brac4g/HONESTY/bart_data/sub-045/045-001_bart/045-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (39)\n',
#  'set feat_files(39) "/scratch/brac4g/HONESTY/bart_data/sub-047/047-001_bart/047-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (40)\n',
#  'set feat_files(40) "/scratch/brac4g/HONESTY/bart_data/sub-048/048-001_bart/048-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (41)\n',
#  'set feat_files(41) "/scratch/brac4g/HONESTY/bart_data/sub-049/049-001_bart/049-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (42)\n',
#  'set feat_files(42) "/scratch/brac4g/HONESTY/bart_data/sub-050/050-001_bart/050-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (43)\n',
#  'set feat_files(43) "/scratch/brac4g/HONESTY/bart_data/sub-051/051-001_bart/051-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (44)\n',
#  'set feat_files(44) "/scratch/brac4g/HONESTY/bart_data/sub-054/054-001_bart/054-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (45)\n',
#  'set feat_files(45) "/scratch/brac4g/HONESTY/bart_data/sub-055/055-001_bart/055-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (46)\n',
#  'set feat_files(46) "/scratch/brac4g/HONESTY/bart_data/sub-057/057-001_bart/057-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (47)\n',
#  'set feat_files(47) "/scratch/brac4g/HONESTY/bart_data/sub-058/058-001_bart/058-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (48)\n',
#  'set feat_files(48) "/scratch/brac4g/HONESTY/bart_data/sub-059/059-001_bart/059-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (49)\n',
#  'set feat_files(49) "/scratch/brac4g/HONESTY/bart_data/sub-060/060-001_bart/060-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (50)\n',
#  'set feat_files(50) "/scratch/brac4g/HONESTY/bart_data/sub-061/061-001_bart/061-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (51)\n',
#  'set feat_files(51) "/scratch/brac4g/HONESTY/bart_data/sub-062/062-001_bart/062-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (52)\n',
#  'set feat_files(52) "/scratch/brac4g/HONESTY/bart_data/sub-063/063-001_bart/063-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (53)\n',
#  'set feat_files(53) "/scratch/brac4g/HONESTY/bart_data/sub-064/064-001_bart/064-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (54)\n',
#  'set feat_files(54) "/scratch/brac4g/HONESTY/bart_data/sub-065/065-001_bart/065-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (55)\n',
#  'set feat_files(55) "/scratch/brac4g/HONESTY/bart_data/sub-066/066-001_bart/066-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (56)\n',
#  'set feat_files(56) "/scratch/brac4g/HONESTY/bart_data/sub-067/067-001_bart/067-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (57)\n',
#  'set feat_files(57) "/scratch/brac4g/HONESTY/bart_data/sub-068/068-001_bart/068-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (58)\n',
#  'set feat_files(58) "/scratch/brac4g/HONESTY/bart_data/sub-069/069-001_bart/069-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (59)\n',
#  'set feat_files(59) "/scratch/brac4g/HONESTY/bart_data/sub-070/070-001_bart/070-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (60)\n',
#  'set feat_files(60) "/scratch/brac4g/HONESTY/bart_data/sub-071/071-001_bart/071-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (61)\n',
#  'set feat_files(61) "/scratch/brac4g/HONESTY/bart_data/sub-073/073-001_bart/073-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (62)\n',
#  'set feat_files(62) "/scratch/brac4g/HONESTY/bart_data/sub-074/074-001_bart/074-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (63)\n',
#  'set feat_files(63) "/scratch/brac4g/HONESTY/bart_data/sub-077/077-001_bart/077-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (64)\n',
#  'set feat_files(64) "/scratch/brac4g/HONESTY/bart_data/sub-078/078-001_bart/078-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (65)\n',
#  'set feat_files(65) "/scratch/brac4g/HONESTY/bart_data/sub-079/079-001_bart/079-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (66)\n',
#  'set feat_files(66) "/scratch/brac4g/HONESTY/bart_data/sub-080/080-001_bart/080-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (67)\n',
#  'set feat_files(67) "/scratch/brac4g/HONESTY/bart_data/sub-081/081-001_bart/081-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (68)\n',
#  'set feat_files(68) "/scratch/brac4g/HONESTY/bart_data/sub-082/082-001_bart/082-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (69)\n',
#  'set feat_files(69) "/scratch/brac4g/HONESTY/bart_data/sub-083/083-001_bart/083-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (70)\n',
#  'set feat_files(70) "/scratch/brac4g/HONESTY/bart_data/sub-084/084-001_bart/084-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (71)\n',
#  'set feat_files(71) "/scratch/brac4g/HONESTY/bart_data/sub-085/085-001_bart/085-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (72)\n',
#  'set feat_files(72) "/scratch/brac4g/HONESTY/bart_data/sub-086/086-001_bart/086-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (73)\n',
#  'set feat_files(73) "/scratch/brac4g/HONESTY/bart_data/sub-087/087-001_bart/087-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (74)\n',
#  'set feat_files(74) "/scratch/brac4g/HONESTY/bart_data/sub-088/088-001_bart/088-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (75)\n',
#  'set feat_files(75) "/scratch/brac4g/HONESTY/bart_data/sub-089/089-001_bart/089-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (76)\n',
#  'set feat_files(76) "/scratch/brac4g/HONESTY/bart_data/sub-090/090-001_bart/090-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (77)\n',
#  'set feat_files(77) "/scratch/brac4g/HONESTY/bart_data/sub-091/091-001_bart/091-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (78)\n',
#  'set feat_files(78) "/scratch/brac4g/HONESTY/bart_data/sub-092/092-001_bart/092-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (79)\n',
#  'set feat_files(79) "/scratch/brac4g/HONESTY/bart_data/sub-093/093-001_bart/093-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (80)\n',
#  'set feat_files(80) "/scratch/brac4g/HONESTY/bart_data/sub-094/094-001_bart/094-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (81)\n',
#  'set feat_files(81) "/scratch/brac4g/HONESTY/bart_data/sub-095/095-001_bart/095-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (82)\n',
#  'set feat_files(82) "/scratch/brac4g/HONESTY/bart_data/sub-096/096-001_bart/096-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (83)\n',
#  'set feat_files(83) "/scratch/brac4g/HONESTY/bart_data/sub-097/097-001_bart/097-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (84)\n',
#  'set feat_files(84) "/scratch/brac4g/HONESTY/bart_data/sub-098/098-001_bart/098-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (85)\n',
#  'set feat_files(85) "/scratch/brac4g/HONESTY/bart_data/sub-100/100-001_bart/100-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (86)\n',
#  'set feat_files(86) "/scratch/brac4g/HONESTY/bart_data/sub-101/101-001_bart/101-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (87)\n',
#  'set feat_files(87) "/scratch/brac4g/HONESTY/bart_data/sub-102/102-001_bart/102-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (88)\n',
#  'set feat_files(88) "/scratch/brac4g/HONESTY/bart_data/sub-104/104-001_bart/104-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (89)\n',
#  'set feat_files(89) "/scratch/brac4g/HONESTY/bart_data/sub-106/106-001_bart/106-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (90)\n',
#  'set feat_files(90) "/scratch/brac4g/HONESTY/bart_data/sub-107/107-001_bart/107-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (91)\n',
#  'set feat_files(91) "/scratch/brac4g/HONESTY/bart_data/sub-108/108-001_bart/108-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (92)\n',
#  'set feat_files(92) "/scratch/brac4g/HONESTY/bart_data/sub-109/109-001_bart/109-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (93)\n',
#  'set feat_files(93) "/scratch/brac4g/HONESTY/bart_data/sub-110/110-001_bart/110-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (94)\n',
#  'set feat_files(94) "/scratch/brac4g/HONESTY/bart_data/sub-111/111-001_bart/111-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (95)\n',
#  'set feat_files(95) "/scratch/brac4g/HONESTY/bart_data/sub-112/112-001_bart/112-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (96)\n',
#  'set feat_files(96) "/scratch/brac4g/HONESTY/bart_data/sub-113/113-001_bart/113-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (97)\n',
#  'set feat_files(97) "/scratch/brac4g/HONESTY/bart_data/sub-114/114-001_bart/114-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (98)\n',
#  'set feat_files(98) "/scratch/brac4g/HONESTY/bart_data/sub-115/115-001_bart/115-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (99)\n',
#  'set feat_files(99) "/scratch/brac4g/HONESTY/bart_data/sub-116/116-001_bart/116-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (100)\n',
#  'set feat_files(100) "/scratch/brac4g/HONESTY/bart_data/sub-117/117-001_bart/117-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (101)\n',
#  'set feat_files(101) "/scratch/brac4g/HONESTY/bart_data/sub-119/119-001_bart/119-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (102)\n',
#  'set feat_files(102) "/scratch/brac4g/HONESTY/bart_data/sub-120/120-001_bart/120-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (103)\n',
#  'set feat_files(103) "/scratch/brac4g/HONESTY/bart_data/sub-121/121-001_bart/121-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (104)\n',
#  'set feat_files(104) "/scratch/brac4g/HONESTY/bart_data/sub-122/122-001_bart/122-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (105)\n',
#  'set feat_files(105) "/scratch/brac4g/HONESTY/bart_data/sub-123/123-001_bart/123-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (106)\n',
#  'set feat_files(106) "/scratch/brac4g/HONESTY/bart_data/sub-125/125-001_bart/125-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (107)\n',
#  'set feat_files(107) "/scratch/brac4g/HONESTY/bart_data/sub-129/129-001_bart/129-001_bart.feat"\n',
#  '\n',
#  '# 4D AVW data or FEAT directory (108)\n',
#  'set feat_files(108) "/scratch/brac4g/HONESTY/bart_data/sub-131/131-001_bart/131-001_bart.feat"\n',
#  '\n',
#  '# Add confound EVs text file\n',
#  'set fmri(confoundevs) 0\n',
#  '\n',
#  '# EV 1 title\n',
#  'set fmri(evtitle1) "Age"\n',
#  '\n',
#  '# Basic waveform shape (EV 1)\n',
#  '# 0 : Square\n',
#  '# 1 : Sinusoid\n',
#  '# 2 : Custom (1 entry per volume)\n',
#  '# 3 : Custom (3 column format)\n',
#  '# 4 : Interaction\n',
#  '# 10 : Empty (all zeros)\n',
#  'set fmri(shape1) 2\n',
#  '\n',
#  '# Convolution (EV 1)\n',
#  '# 0 : None\n',
#  '# 1 : Gaussian\n',
#  '# 2 : Gamma\n',
#  '# 3 : Double-Gamma HRF\n',
#  '# 4 : Gamma basis functions\n',
#  '# 5 : Sine basis functions\n',
#  '# 6 : FIR basis functions\n',
#  '# 8 : Alternate Double-Gamma\n',
#  'set fmri(convolve1) 0\n',
#  '\n',
#  '# Convolve phase (EV 1)\n',
#  'set fmri(convolve_phase1) 0\n',
#  '\n',
#  '# Apply temporal filtering (EV 1)\n',
#  'set fmri(tempfilt_yn1) 0\n',
#  '\n',
#  '# Add temporal derivative (EV 1)\n',
#  'set fmri(deriv_yn1) 0\n',
#  '\n',
#  '# Custom EV file (EV 1)\n',
#  'set fmri(custom1) "dummy"\n',
#  '\n',
#  '# Orthogonalise EV 1 wrt EV 0\n',
#  'set fmri(ortho1.0) 0\n',
#  '\n',
#  '# Orthogonalise EV 1 wrt EV 1\n',
#  'set fmri(ortho1.1) 0\n',
#  '\n',
#  '# Orthogonalise EV 1 wrt EV 2\n',
#  'set fmri(ortho1.2) 0\n',
#  '\n',
#  '# Orthogonalise EV 1 wrt EV 3\n',
#  'set fmri(ortho1.3) 0\n',
#  '{sub_stat_1}\n',
#  '\n',
#  '# EV 2 title\n',
#  'set fmri(evtitle2) "Gender"\n',
#  '\n',
#  '# Basic waveform shape (EV 2)\n',
#  '# 0 : Square\n',
#  '# 1 : Sinusoid\n',
#  '# 2 : Custom (1 entry per volume)\n',
#  '# 3 : Custom (3 column format)\n',
#  '# 4 : Interaction\n',
#  '# 10 : Empty (all zeros)\n',
#  'set fmri(shape2) 2\n',
#  '\n',
#  '# Convolution (EV 2)\n',
#  '# 0 : None\n',
#  '# 1 : Gaussian\n',
#  '# 2 : Gamma\n',
#  '# 3 : Double-Gamma HRF\n',
#  '# 4 : Gamma basis functions\n',
#  '# 5 : Sine basis functions\n',
#  '# 6 : FIR basis functions\n',
#  '# 8 : Alternate Double-Gamma\n',
#  'set fmri(convolve2) 0\n',
#  '\n',
#  '# Convolve phase (EV 2)\n',
#  'set fmri(convolve_phase2) 0\n',
#  '\n',
#  '# Apply temporal filtering (EV 2)\n',
#  'set fmri(tempfilt_yn2) 0\n',
#  '\n',
#  '# Add temporal derivative (EV 2)\n',
#  'set fmri(deriv_yn2) 0\n',
#  '\n',
#  '# Custom EV file (EV 2)\n',
#  'set fmri(custom2) "dummy"\n',
#  '\n',
#  '# Orthogonalise EV 2 wrt EV 0\n',
#  'set fmri(ortho2.0) 0\n',
#  '\n',
#  '# Orthogonalise EV 2 wrt EV 1\n',
#  'set fmri(ortho2.1) 0\n',
#  '\n',
#  '# Orthogonalise EV 2 wrt EV 2\n',
#  'set fmri(ortho2.2) 0\n',
#  '\n',
#  '# Orthogonalise EV 2 wrt EV 3\n',
#  'set fmri(ortho2.3) 0\n',
#  '{sub_stat_2}\n',
#  '\n',
#  '# EV 3 title\n',
#  'set fmri(evtitle3) "{covariate}"\n',
#  '\n',
#  '# Basic waveform shape (EV 3)\n',
#  '# 0 : Square\n',
#  '# 1 : Sinusoid\n',
#  '# 2 : Custom (1 entry per volume)\n',
#  '# 3 : Custom (3 column format)\n',
#  '# 4 : Interaction\n',
#  '# 10 : Empty (all zeros)\n',
#  'set fmri(shape3) 2\n',
#  '\n',
#  '# Convolution (EV 3)\n',
#  '# 0 : None\n',
#  '# 1 : Gaussian\n',
#  '# 2 : Gamma\n',
#  '# 3 : Double-Gamma HRF\n',
#  '# 4 : Gamma basis functions\n',
#  '# 5 : Sine basis functions\n',
#  '# 6 : FIR basis functions\n',
#  '# 8 : Alternate Double-Gamma\n',
#  'set fmri(convolve3) 0\n',
#  '\n',
#  '# Convolve phase (EV 3)\n',
#  'set fmri(convolve_phase3) 0\n',
#  '\n',
#  '# Apply temporal filtering (EV 3)\n',
#  'set fmri(tempfilt_yn3) 0\n',
#  '\n',
#  '# Add temporal derivative (EV 3)\n',
#  'set fmri(deriv_yn3) 0\n',
#  '\n',
#  '# Custom EV file (EV 3)\n',
#  'set fmri(custom3) "dummy"\n',
#  '\n',
#  '# Orthogonalise EV 3 wrt EV 0\n',
#  'set fmri(ortho3.0) 0\n',
#  '\n',
#  '# Orthogonalise EV 3 wrt EV 1\n',
#  'set fmri(ortho3.1) 0\n',
#  '\n',
#  '# Orthogonalise EV 3 wrt EV 2\n',
#  'set fmri(ortho3.2) 0\n',
#  '\n',
#  '# Orthogonalise EV 3 wrt EV 3\n',
#  'set fmri(ortho3.3) 0\n',
#  '{sub_stat_3}\n',
#  '\n',
#  '# Setup Orthogonalisation at higher level? \n',
#  'set fmri(level2orth) 0\n',
#  '{sub_mem}\n',
#  '\n',
#  '# Contrast & F-tests mode\n',
#  '# real : control real EVs\n',
#  '# orig : control original EVs\n',
#  'set fmri(con_mode_old) real\n',
#  'set fmri(con_mode) real\n',
#  '\n',
#  '# Display images for contrast_real 1\n',
#  'set fmri(conpic_real.1) 1\n',
#  '\n',
#  '# Title for contrast_real 1\n',
#  'set fmri(conname_real.1) "Age"\n',
#  '\n',
#  '# Real contrast_real vector 1 element 1\n',
#  'set fmri(con_real1.1) 1\n',
#  '\n',
#  '# Real contrast_real vector 1 element 2\n',
#  'set fmri(con_real1.2) 0\n',
#  '\n',
#  '# Real contrast_real vector 1 element 3\n',
#  'set fmri(con_real1.3) 0\n',
#  '\n',
#  '# Display images for contrast_real 2\n',
#  'set fmri(conpic_real.2) 1\n',
#  '\n',
#  '# Title for contrast_real 2\n',
#  'set fmri(conname_real.2) "Gender"\n',
#  '\n',
#  '# Real contrast_real vector 2 element 1\n',
#  'set fmri(con_real2.1) 0\n',
#  '\n',
#  '# Real contrast_real vector 2 element 2\n',
#  'set fmri(con_real2.2) 1\n',
#  '\n',
#  '# Real contrast_real vector 2 element 3\n',
#  'set fmri(con_real2.3) 0\n',
#  '\n',
#  '# Display images for contrast_real 3\n',
#  'set fmri(conpic_real.3) 1\n',
#  '\n',
#  '# Title for contrast_real 3\n',
#  'set fmri(conname_real.3) "{covariate}"\n',
#  '\n',
#  '# Real contrast_real vector 3 element 1\n',
#  'set fmri(con_real3.1) 0\n',
#  '\n',
#  '# Real contrast_real vector 3 element 2\n',
#  'set fmri(con_real3.2) 0\n',
#  '\n',
#  '# Real contrast_real vector 3 element 3\n',
#  'set fmri(con_real3.3) 1\n',
#  '\n',
#  '# Contrast masking - use >0 instead of thresholding?\n',
#  'set fmri(conmask_zerothresh_yn) 0\n',
#  '\n',
#  '# Mask real contrast/F-test 1 with real contrast/F-test 2?\n',
#  'set fmri(conmask1_2) 0\n',
#  '\n',
#  '# Mask real contrast/F-test 1 with real contrast/F-test 3?\n',
#  'set fmri(conmask1_3) 0\n',
#  '\n',
#  '# Mask real contrast/F-test 2 with real contrast/F-test 1?\n',
#  'set fmri(conmask2_1) 0\n',
#  '\n',
#  '# Mask real contrast/F-test 2 with real contrast/F-test 3?\n',
#  'set fmri(conmask2_3) 0\n',
#  '\n',
#  '# Mask real contrast/F-test 3 with real contrast/F-test 1?\n',
#  'set fmri(conmask3_1) 0\n',
#  '\n',
#  '# Mask real contrast/F-test 3 with real contrast/F-test 2?\n',
#  'set fmri(conmask3_2) 0\n',
#  '\n',
#  '# Do contrast masking at all?\n',
#  'set fmri(conmask1_1) 0\n',
#  '\n',
#  '##########################################################\n',
#  "# Now options that don't appear in the GUI\n",
#  '\n',
#  '# Alternative (to BETting) mask image\n',
#  'set fmri(alternative_mask) ""\n',
#  '\n',
#  '# Initial structural space registration initialisation transform\n',
#  'set fmri(init_initial_highres) ""\n',
#  '\n',
#  '# Structural space registration initialisation transform\n',
#  'set fmri(init_highres) ""\n',
#  '\n',
#  '# Standard space registration initialisation transform\n',
#  'set fmri(init_standard) ""\n',
#  '\n',
#  '# For full FEAT analysis: overwrite existing .feat output dir?\n',
#  'set fmri(overwrite_yn) 0\n']

# %%
type(str(info))
# Out:
# str

# %%
type(line_sub)
# Out:
# str

# %%
with open(fsf_out_file,"w") as file:
    # open(fsf_out_file,"w").close()
    # for line in line_sub:
        # file.writelines(line)
    file.writelines(new_lines)
    file.close()

# %%
def write_file(text_list,out_file):
    '''
    working doc-string
    '''
    
    with open(out_file,"w") as file:
        file.writelines(text_list)
        file.close()
    return out_file

# %%
def regex_replace(pattern,file,repl_list):
    '''
    working doc-string
    '''
    
    regexp = re.compile(f"{pattern}")
    new_lines = list()
    with open(file,"r") as f:
        for line in f:
            match = regexp.match(line)
            if match:
                new_lines.extend(repl_list)
            else:
                new_lines.append(line)
        f.close()
    return new_lines
